# %% [markdown]
# #### Aline Rockenzahn Gallegos
# #### Jueves 29 AGosto 2024

# %% [markdown]
# # <div align ="center"> T02-PYTHON

# %% [markdown]
# **1. Graficar las siguientes funciones f(x). Determina el dominio a partir de la función:**

# %% [markdown]
# ![Screen Shot 2024-08-29 at 13.32.26.png](attachment:bf1c0f25-f3a4-4f1a-a88e-088e1f569a0c.png)

# %% [markdown]
# ![Screen Shot 2024-08-29 at 15.17.05.png](attachment:2018b6cf-28e8-49e6-bce4-dccf766d6173.png)

# %%
#Primero voy a importar todas las librerías que necesito 
import sympy as sp #Simpy lo voy a usar para escribir las funciones de forma "bonita" 
import numpy as np #Numpy es para hacer arreglos, entonces ne sirve para definir mis variables en ciertos rangos y luego graficarlo con matplotlib
import matplotlib.pyplot as plt #Esta es para graficar las funciones 

#def f1(x) :
    #return x**2-4x+2

# %%
import sympy as sp 
sp.var("x") #Esto es para crear un símbolo "x" en sympy y poder escribir la función bonita 
y1 = x**2-4*x+2
y1
# Out:
# x**2 - 4*x + 2

# %%
x = np.linspace(-1, 5, 100) #Esta variable es como los arreglos en matlab, el formato es primero el valor de inicio, luego el final, y al último los espacios que queremos entre cada valor 
y1 = x**2 - 4*x + 2

plt.figure(figsize=(5, 4)) 
plt.plot(x, y1, label=r'$y(x)= x^2 - 4x + 2$')
plt.axhline(0, color='red', linewidth=0.5)  #Esta línea y la de abajo es para marcar el origen en la gráfica 
plt.axvline(0, color='red', linewidth=0.5)  
plt.grid(True)  


plt.legend()

plt.show()

# %%
import sympy as sp 
import math 
sp.var("x") #Vuelvo a crear el símbolo 
y2 = sp.sin(3*x) #No te salía porque no le habías puesto el sp antes del sin. Tienes que pasar la función de python a símbolo sp tmbn 
y2
# Out:
# sin(3*x)

# %%
x = np.linspace(-1, 5, 100)
y2 = np.sin(3*x)

plt.figure(figsize=(5, 4)) 
plt.plot(x, y2, label=r'$y(x)= sin(3x)$')
plt.axhline(0, color='red', linewidth=1)  
plt.axvline(0, color='red', linewidth=1)  
plt.grid(True)  
plt.legend()

plt.show()

# %%
import sympy as sp 
import math 
sp.var("x") 
y3 = sp.exp(2*x)-3
y3
# Out:
# exp(2*x) - 3

# %%
x = np.linspace(-1, 5, 100)
y3 = np.exp(2*x)-3

plt.figure(figsize=(5, 4)) 
plt.plot(x, y3, label=r'$y(x) = e^{2x}$')
plt.axhline(0, color='red', linewidth=1)  
plt.axvline(0, color='red', linewidth=1)  
plt.grid(True)  
plt.legend()

plt.show()

# %%
import sympy as sp 
import math 
sp.var("x") 
y4 = sp.sqrt((x**2)-4)
y4
# Out:
# sqrt(x**2 - 4)

# %%
x = np.linspace(-1, 5, 100)
y4 = np.sqrt(np.maximum(x**2 - 4, 0))

plt.figure(figsize=(5, 4)) 
plt.plot(x, y4, label=r'$y(x) = \sqrt{x^2-4}$')
plt.axhline(0, color='red', linewidth=1)  
plt.axvline(0, color='red', linewidth=1)  
plt.grid(True)  
plt.legend()

plt.show()

# %%
import sympy as sp 
import math 
sp.var("x") 
y5 = sp.cos(x+(sp.pi/4)) #Te pasó lo mismo con el pi jajaja cada valor simbólico de python, hay que definirlo como símbolo sp tmbn 
y5
# Out:
# cos(x + pi/4)

# %%
x = np.linspace(-1, 5, 100)
y5 = np.cos(x+ np.pi/4)

plt.figure(figsize=(5, 4)) 
plt.plot(x, y5, label=r'$y(x) = cos(x + \frac{\pi}{4})$')
plt.axhline(0, color='red', linewidth=1)  
plt.axvline(0, color='red', linewidth=1) 
plt.grid(True)  
plt.legend()

plt.show()

# %% [markdown]
# **2. Graficar los siguientes grupos de funciones:**
# #### **Grupo1**

# %% [markdown]
# ![Screen Shot 2024-08-29 at 14.11.14.png](attachment:02e82f96-1683-4e68-a5e3-9e9f882ab746.png)

# %%
x = np.linspace(-1, 5, 100)
g1 = 2*x + 1
g2 = -x  + 4
g3 = x**2
plt.figure(figsize=(5, 4))
plt.plot(x, g1, label=r'$y(x) = 2x + 1$')
plt.plot(x, g2, label = r'$y(x) = -x + 4$')
plt.plot(x,g3, label = r'$y(x) = x^2$')
plt.axhline(0, color='red', linewidth=1)  
plt.axvline(0, color='red', linewidth=1) 
plt.grid(True)  

plt.legend()

plt.show()

# %% [markdown]
# #### **Grupo2**

# %% [markdown]
# ![Screen Shot 2024-08-29 at 14.13.17.png](attachment:705f15aa-62d6-46ae-8c53-fbddb91a8409.png)

# %%
x = np.linspace(-1, 5, 100)
g4 = np.sin(x)
g5 = np.cos(x)
plt.figure(figsize=(5, 4))
plt.plot(x, g4, label=r'y(x) = sin(x)$')
plt.plot(x, g5, label = r'y(x) = cos(x)$')
plt.axhline(0, color='red', linewidth=1)  
plt.axvline(0, color='red', linewidth=1) 
plt.grid(True)  

plt.legend()

plt.show()

# %% [markdown]
# **3. Crea una función que cree una gráfica y dibuje 'k' líneas de forma f(x)=sin(alpha*x) La función recibe:**
# 1. x1: valor inicial de 'x'
# 2. x2: valor final de 'x'
# 3. n: cantidad de puntos del vector 'x'
# 4. a: valor inicial de alpha
# 5. b: valor final de alpha
# 6. k: cantidad de líneas
# Usar el la variable opcional de "label" y el comando de legend para saber qué línea pertenece a qué alpha

# %%
def mi_funcion(xi, xf, n, ai, af):
 
    x = np.linspace(xi, xf, n)
    
    alphas = np.linspace(ai, af, 5)  
    
    plt.figure(figsize=(10, 6))
    
    for alpha in alphas:
        seno_alphas = np.sin(alpha * x)
        
        plt.plot(x, seno_alphas, label=r'y(x) = sin({:.2f}'.format(alpha))
        
    plt.axhline(0, color='red', linewidth=1)  
    plt.axvline(0, color='red', linewidth=1)  
    plt.grid(True)
    
    plt.title('Seno en funcion de x')
    plt.xlabel('x')
    plt.ylabel('y(x)')
    plt.legend()
    
    plt.show()

mi_funcion(-1, 5, 100, 1, 2)
