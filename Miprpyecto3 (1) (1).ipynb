# %% [markdown]
# # <div align ="center">**Cálculo de grosores de un metamaterial para minimizar su reflectancia en 600 nm**

# %% [markdown]
# Aline Quetzalli Rockenzahn Gallegos
# Lunes 2 Diciembre 2024

# %% [markdown]
# ![Captura de pantalla 2024-11-30 233719.png](attachment:eb60a8b6-8847-477b-8edf-8e63012a314c.png)

# %% [markdown]
# ## INTRODUCCIÓN
#
# Desde el inicio de este curso de Simulación Matemática, tuve el deseo de poder crear un código que me permitiera encontrar la respuesta a un problema que otro profesor de mi carrera de Ingeniería en Nanotecnología me había retado a hacer: diseñar un metamaterial entre Au y SiO2 que reflejara el mínimo de luz incidente a 600 nm. Al inicio pensé que sería imposible porque era mi segunda clase de programación en la vida, pero increíblemente con los conocimientos que aprendí estos 4 meses, fue suficiente para darme cuenta que ya podía utilizar la programación como una herramienta más en mi repertorio para solucionar los problemas. El código fue un éxito, y por lo tanto siempre le estaré agradecida a esta clase. No sólo por lo que aprendí en conocimiento, sino también por la lección acerca de que no importa qué tan dificil parezca una materia al inicio o qué tan incapaz te sientas en una situación, si genuinamente lo intentas no hay manera de no lograrlo. Gracias.
#
# Para empezar, el interés en diseñar el metamaterial surgió a raíz de las propiedades especiales de estos compuestos. Estos materiales son denominados "artificiales" debido a que no se encuentran en la naturaleza. Pero esto también significa que presentan propiedades nuevas no vistas antes. Estos también denominados "materiales del futuro" tienen sobre todo propiedades electromagnéticas especiales que se derivan de su forma, estructura y unión de los diferentes elementos que los componen.
#
# En los últimos años se han estudiado mucho estos materiales y descubierto varias propiedades importantes como por ejemplo:
# - Debido a sus propiedades ópticas como reflexión o transmición de la luz, pueden volverse invisibles en el espectro visible. Pero no sólo eso, sino que al interactuar con otros objetos pueden hacerlos invisibles también. Explicado de otra forma, si se resubriera algún objeto con un metamaterial específico, permitiría que la luz pasara directamente a través de ambos sin deformarla haciendo imposible ver ambos objetos bajo ciertas circunstancias.
# - Son capaces de controlar el sonido. Bajo ciertas circunstancias son capaces de sumprimir o amplificar ciertos sonidos.
# - Son los únicos materiales que tienen permitividad eléctrica y prmeabilidad magnética negativas. Esto se traduce en que pueden tener índices de refracció negativos por ejemplo.
#
# Además, estos metamateriales son una área de investigación bastante nueva que se cree tendrá un impacto muy fuerte en nuestro futuro. La nanotecnología juega un papel importante en investigar, crear, busca mejorar y transformar los materiales tal como los conocemos, y aunque estamos apenas comenzando a entender su verdadero alcance, las aplicaciones que se vislumbran son muy interesantes.
#
# Uno de los usos más prometedores de estos materiales se cree que está en el ámbito militar, donde podrían revolucionar las capacidades de camuflaje, defensa y vigilancia al modificar la visibilidad de los objetos. Esta misma capacidad de invisibilidad se está evaluando en la industria de la moda, donde se podrían crear prendas de ropa que cambien la apariencia de las personas o incluso sean completamente transparentes, o incluso en tratamientos de belleza.
#
# También hay aplicaciones que impactarían sectores como la automoción. Los metamateriales podrían mejorar la seguridad en los vehículos al eliminar los puntos ciegos en los retrovisores, lo que aumentaría la visibilidad y reduciría accidentes. Otro de los campos con gran potencial es el de la óptica, ya que se podrían crear lentes y cámaras de alta resolución, o incluso sistemas médicos de diagnóstico por imagen mucho más avanzados.Además, los metamateriales permitirían innovar en las telecomunicaciones, ya que estos materiales podrían facilitar la creación de antenas más precisas y potentes.
#
# Debido a todas estas propiedades increíbles, y la gran relación del tema con mi área de estudio me di a la tarea de investigar y comprender al menos un poco la parte matemática de estos materiales con la meta de lograr diseñar alguno para poder crearlo en un laboratorio en el futuro.

# %% [markdown]
# ## MARCO TEÓRICO
#
# Los conceptos básicos y fundamentales que se tienen que saber para poder comprender el modelo detrás de la creación del metamaterial son los conceptos de dieléctrico, índice de refracción, números complejos, periodos, constante dieléctrica y la ecuación de Fresnel.
#
# Para empezar la razón de utilizar oro como el metal para el metamaterial se debe a que es un muy buen conductor de calor, a diferencia de otros metales como la plata (Ag) es muy resistentea la corrosión y oxidación, pero sobre todo por su capacidad de generar resonancias plasmónicas de superficie. Explicar este concepto anterior es un poco complicado, así que bastará con decir que es un fenómeno que sirve para amplificar muy fuertemente el campo electromagnético alrededor de ciertos puntos del metal, lo cual es útil para muchas aplicaciónes (Maldonado, 2024). Además la razón de utilizar SiO2 junto con el oro, es debido a que éste es un dieléctrico capaz de amplificar la generación e intensidad de los plasmones de superficie. Un dieléctrico se define como un material que no conduce electricidad pero puede ser polarizado por un campo eléctrico. Es decir, aunque no conduzca corriente, las cargas dentro de él se pueden alinear para crear un campo eléctrico interno. Se utilizan en los metamateriales par por ejemplo concentrar ondas electromagnéticas en puntos específicos, permiten a los ingenieros diseñar materiales con ondas electromagnéticas personalizadas y al ser malos conductores, evitan la pérdida de energía por conducción (JL, 2024).
#
# Los periodos por otra parte, se refieren a que en un metamaterial no hay únicamente una capa de cada componente. Se podrían por ejemplo tener 4 capas de oro y 3 de dieléctrico, o 2 capas de oro y 1 de dieléctrico, y esta característica afecta enormemente las propiedades del material. Sin embargo, en el cálculo de los grosores esta cualidad no se toma en cuenta (como se verá matemáticamente más adelante) ya que se toma en cuenta la fracción de llenado total de cada material.
#
# La constante dieléctrica también conocida como permitividad relativa, es una medida de cuánto un material puede ser polarizado por un campo eléctrico. Un material con una alta constante dieléctrica reduce más el campo eléctrico en su interior comparado con uno con una constante baja (Ingenierizando, 2024).
#
# El índice de refracción se define como el cociente de la velocidad de la luz cuando pasa a través de dos medios, o en otras palabras, define la rapidez con la que un haz de luz viaja a través de los medios, y esta relación se describe mediante la fórmula:
# $$n=c/v$$
# Donde:
# n es el índice de refracción, c es la velocidad de la luz en un vacío o aire, v es al velocidad de la luz en los medios (por ejemplo agua, aceite de oliva etc...). Indica cuánto se reduce la velocidad de la luz (o de otras ondas) al pasar de un medio a otro, no tiene unidades y es adimensional, además varía con la longitud de onda de la luz (Ingenierizando, 2023).
#
# Otro concepto importante es el de los números complejos. Debido a que la mayoría de variables en el cálculo del metamaterial tienen partes imaginarias (como los índices de refracción o constantes dieléctricas) es importante definirlos. Estos  números complejos son una extensión de los números reales que incluyen una parte real y una parte imaginaria. Se representan generalmente en la forma a + bi, donde a es la parte real y bi es la parte imaginaria, con b como un número real y i como la unidad imaginaria, definida por la propieda i^2=1
#
# Las ecuaciones de Fresnel se presentan en dos formas principales: para la componente perpendicular y para la componente paralela al plano de incidencia (Wikpedia, s.f).
#
# Se ueden realizar operaciones matemáticas normales con estos números como suma, resta, multiplicación etc... pero hay que tener cuidado con las reglas especiales que se tienen que seguir.
#
# Finalmente las ecuaciónes de Fresnel son un conjunto de ecuaciones que describen cómo la luz se refleja y se refracta en la interfaz entre dos medios con diferentes índices de refracción:
#
# Las ecuaciones de Fresnel se presentan en dos formas principales: para la componente perpendicular y para la componente paralela al plano de incidencia.
#
# ### Componente Perpendicular (s-polarización):
#
# Coeficiente de reflexión:
# $$
# R_s = \left( \frac{n_1 \cos \theta_i - n_2 \cos \theta_t}{n_1 \cos \theta_i + n_2 \cos \theta_t} \right)^2
# $$
#
# Coeficiente de transmisión:
# $$
# T_s = \left( \frac{2n_1 \cos \theta_i}{n_1 \cos \theta_i + n_2 \cos \theta_t} \right)^2
# $$
#
# ### Componente Paralela (p-polarización):
#
# Coeficiente de reflexión:
# $$
# R_p = \left( \frac{n_2 \cos \theta_i - n_1 \cos \theta_t}{n_2 \cos \theta_i + n_1 \cos \theta_t} \right)^2
# $$
#
# Coeficiente de transmisión:
# $$
# T_p = \left( \frac{2n_1 \cos \theta_i}{n_2 \cos \theta_i + n_1 \cos \theta_t} \right)^2
# $$theta_t} \right)^2
# $$
#
# En este proyecto se utilizó una variación de las ecuaciónes de Fresnel que no incluye ángulos, la cual se mostrará y explicará más adelante

# %% [markdown]
# ## OBJETIVO GENERAL
# Como ya se había mencionado anteriormente, la meta del proyecto es poder diseñar un metamaterial de oro y dióxido de silicio, optimizando sus grosores dentro de los límites establecidos para minimizar la luz que refleja el material final a 600 nanómetros. Por ello, el **objetivo principal** será crear un código que me permita comparar todos los grosores posibles y encontrar el resultado esperado.

# %% [markdown]
# ## OBJETIVOS ESPECÍFICOS
# 1. Encontrar una función a trozos para el índice de refracción del Au entre el dominio de 300-826 nanómetros por medio del mísmo método de regresiones lineales que se realizaron en el proyecto 1 de esta materia.
#
# 2. Reportar los valores de las funciones a trozos del IR del Au u Si y crear una función para cada uno que reciba la longitud de onda de entrada y devuelva el IR como el número complejo correspondiente.
#
# 3. Realizar una prueba individual con grosores aleatorios para encontrar la reflección a 600nm por medio de la definición y establecimiento correcto de cada una de las operaciones matemáticas necesarias en el proceso.
#
# 4. Automatizar el cálculo de la reflección a 600nm para cualquier valor de grosores al establecer una función R general que tome como entrada los grosores y regrese la reflección como valor de salida.
#
# 5. Comparar todas las combinaciones posibles de grosores al obtener la reflectancia para cada uno de ellos y encontrar el valor mínimo entre todos.
#
# 6. Mostrar de manera visual la solución encontrada por medio de una gráfica comparando la longitud de onda con la respectiva reflectancia.
# 7. Mostrar de manera visual en un mismo plano todas las funciones de reflectancia posibles para los grosores de los materiales.
#
# 8. Utilizar algún otro método de programación a disposición para obtener el mismo resultado de reflectancia mínima a 600nm y los respectivos grosores utilizados.

# %% [markdown]
# ## DESCRIPCIÓN DEL MODELO
# El modelo comienza por delimitar los rangos de los grosores de cada material:
# $$40 \text{ nm}\geq  t_Au \geq  5 \text{ nm}$$
# $$100 \text{ nm}\geq  t_SiO2 \geq  5 \text{ nm}$$
# Con los grosores individuales se obtienen las respectivas fracciones de llenado:
# $$f_Au = \frac{t_{Au}}{t_{Au}+t_{SiO2}} $$
# $$f_Au = \frac{t_{SiO2}}{t_{Au}+t_{SiO2}} $$
# Las fracciones de llenado siempre deben dar un número entre 0 y 1.
# La suma de ambas fracciones de llenado debe dar 1.
# $n_{SiO2} = 4691$ Se maneja como una constante porque varía muy poco entre 300nm y 1000 nm
# $$n_{SiO2}(300nm) = 1.4878$$
# $$n_{SiO2}(1000nm) = 1.4504$$
# Promedio = 1.4691
# $\epsilon_{SiO2} = 2.46$ También se maneja como una constante
# $n_{Au}$ es un número complejo de forma $a+ bi$. Con el IR se saca la constante dieléctrica $\epsilon_{Au}$ que también es un número complejo
# La relación entre IR y su valor $\epsilon$ es: $\epsilon = n^2$
# $\epsilon_{Au} = n_{Au}^2$ También es un número complejo en la forma a + bi
# Se saca $\epsilon_{metamaterial}$ para después sacar su n
# $$\epsilon_{meta} = f_{Au}* \epsilon{Au} + f_{SiO2} * \epsilon_{SiO2}$$
# n_2 es el IR del metamaterial
# $$n_{meta} = \sqrt{\epsilon_{meta}} = n_2 $$
# $$n_{aire} = 1 = n_1$$
# $$n_{meta} = n_2 $$
# $$n_{Si} = n_3 $$
# Beta es un valor imaginario utilizado en la ecuación final de Fresnel
# $$\beta = \frac{2*\pi}{\lambda} * n_2 * h $$
# h es el grosor total del metamaterial definido por:
# $$t_{Au} + t_{SiO2}$$
# La ecuación final, o la función de costo es la ecuación de Fresnel a continuación:
# $$R(\lambda) =  \left| \frac{r_{12}+r_{23}*e^{2i\beta}}{1+r_{12}*r_{23}*e^{2i\beta}} \right|^2$$
# En donde:
# $$r_{ij} = \frac{n_i-n_j}{n_1+n_2}$$
# $$r_{12} = \frac{n_1-n_2}{n_i+n_j}$$
# $$r_{23} = \frac{n_2-n_3}{n_2+n_3}$$
# R termina siendo un valor real que depende de las variables $\lambda$, $t_{Au}$, $t_{SiO2}$

# %% [markdown]
# ## SIMULACIÓN Y OPTIMIZACIÓN DEL MODELO (CON VISUALIZACIONES)

# %%
import numpy as np 
import random 
import matplotlib.pyplot as plt
import cmath

# %% [markdown]
# El código para este proyecto comienza con retomar la función a trozos obtenida para el índice de refracción del Silicio (Si) que se calculó en el proyecto número 1 de la clase de Simulación Matemática. La función se puede observar a continuación:

# %% [markdown]
# #### SILICIO PARTE REAL
# f(lambda) = 0.001822571095590312 x +4.454614314767349
# f(lambda) = 0.000618203780107485 x +4.818942820547491
# f(lambda) = 0.005708934527578188 x +3.2016883049663685
# f(lambda) = 0.010208727259668298 x +1.7345029677801058
# f(lambda) = 0.015036937195248642 x +0.11719884130964744
# f(lambda) = 0.031927106907187 x -5.699110591324737
# f(lambda) = 0.08675223409221743 x -25.117063013351682
# f(lambda) = 0.016905432699586723 x +0.35713481315349227
# f(lambda) = -0.05492198522583452 x +27.34375154035692
# f(lambda) = -0.03976769306307591 x +21.47256873632867
# f(lambda) = -0.026052616514425808 x +15.989021493932546
# f(lambda) = -0.01846122925053561 x +12.852644505769854
# f(lambda) = -0.013667242550391284 x +10.804328308652249
# f(lambda) = -0.010433618620805059 x +9.373589774221077
# f(lambda) = -0.0062816645604509246 x +7.445283320179863
# f(lambda) = -0.0028977603536213038 x +5.686415779588927
# f(lambda) = -0.0013721892566664834 x +4.745901802879681
# f(lambda) = -0.0008153384626206141 x +4.346310860361642
#
# #### SILICIO PARTE IMAGINARIA
# f(lambda) = -0.05833779750805829 x +21.649888273827735
# f(lambda) = -0.030521034590783765 x +13.048106706630055
# f(lambda) = -0.019655369361894957 x +9.595022091586962
# f(lambda) = -0.014217280735998934 x +7.821682533701889
# f(lambda) = -0.00775110083572566 x +5.655958632432424
# f(lambda) = 0.0026395512141405863 x +2.0785230634025753
# f(lambda) = -0.0295293270322416 x +13.473858042631385
# f(lambda) = -0.12601733114333966 x +48.664145747960795
# f(lambda) = -0.05856822027610789 x +23.324660474906203
# f(lambda) = -0.019687047921568307 x +8.259318744123897
# f(lambda) = -0.008888435003924448 x +3.9420652908662266
# f(lambda) = -0.004726401359058814 x +2.223006996374033
# f(lambda) = -0.0026868498573450997 x +1.3522104280421496
# f(lambda) = -0.002079958900000417 x +1.084589239597811
# f(lambda) = -0.001078816688372149 x +0.6110485067532602
# f(lambda) = -0.00033952120568173344 x +0.22957403119180284
# f(lambda) = -0.00010157815841204854 x +0.08323363447747698
# f(lambda) = -5.7902775623551065e-05 x +0.05273253034746406
#
# #### MIS DOMINIOS
# x_ranges = [(300, 310), (310, 317.90), (317.90, 326.30), (326.30, 335.10),
#             (335.10, 344.40), (344.40, 354.20), (354.20, 364.70), (364.70, 375.70),
#             (375.70, 387.50), (387.50, 399.90), (399.90, 413.30), (413.30, 427.50),
#             (427.50, 442.80), (442.80, 459.20), (459.20, 516.60), (516.60, 619.90),
#             (619.90, 729.30), (729.30, 826.6)]

# %% [markdown]
# Sin embargo, no se tenía una función suficientemente exacta para el índice de refracción del oro. Por lo que se procedió a sacar una función a trozos para este caso también por medio de varias regresiones lineales.

# %%
#DOMINIOS PARA EL ORO 
#de 300 a 826.6 

#MIS DOMINIOS 
import numpy as np 

dom_oro_1 = np.array([0.300,0.30204,0.30408,0.30612,0.30816,0.3102,0.31224,0.31428,0.31632,0.31836,0.3204])
n_oro_1 = np.array([1.5258,1.5300,1.5300,1.5300,1.5300,1.5300,1.5316,1.5337,1.5358,1.5379,1.5400 ])
k_oro_1 = np.array([1.8878,1.8895,1.8903,1.8911,1.8920,1.8928,1.8938,1.8948,1.8959,1.8969,1.8980])

dom_oro_2 = np.array([0.3204,0.32378,0.32716,0.33054,0.33392,0.3373,0.34068,0.34406,0.34744,0.35082,0.3542])
n_oro_2 = np.array([1.5400,1.5217,1.5035,1.4852,1.4800,1.4800,1.4800,1.4827,1.4884,1.4942,1.5000])
k_oro_2 = np.array([1.8980,1.8934,1.8889,1.8843,1.8804,1.8767,1.8730,1.8703,1.8689,1.8674,1.8660])

dom_oro_3 = np.array([0.35420,0.35693,0.35966,0.36239,0.36512,0.36785,0.37058,0.37331,0.37604,0.37877,0.3815])
n_oro_3 = np.array([1.5000,1.4960,1.4920,1.4880,1.4841,1.4801,1.4761,1.4720,1.4680,1.4640,1.4600,])
k_oro_3 = np.array([1.8660,1.8718,1.8776,1.8833,1.8891,1.8949,1.9025,1.9101,1.9177,1.9254,1.9330])

dom_oro_4 = np.array([0.38150,0.38309,0.38468,0.38627,0.38786,0.38945,0.39104,0.39263,0.39422,0.39581,0.3974])
n_oro_4 = np.array([1.4600,1.4610,1.4620,1.4630,1.4640,1.4650,1.4660,1.4670,1.4680,1.4690,1.4700,])
k_oro_4 = np.array([1.9330,1.9349,1.9368,1.9387,1.9406,1.9425,1.9444,1.9463,1.9482,1.9501,1.9520])

dom_oro_5 = np.array([0.39740,0.39899,0.40058,0.40217,0.40376,0.40535,0.40694,0.40853,0.41012,0.41171,0.41330])
n_oro_5 = np.array([1.4700,1.4690,1.4680,1.4670,1.4660,1.4650,1.4640,1.4630,1.4620,1.4610,1.4600])
k_oro_5 = np.array([1.9520,1.9526,1.9532,1.9538,1.9544,1.9550,1.9556,1.9562,1.9568,1.9574,1.9580])

dom_oro_6 = np.array([0.41330,0.41502,0.41674,0.41846,0.42018,0.4219,0.42362,0.42534,0.42706,0.42878,0.4305])
n_oro_6 = np.array([1.4600,1.4590,1.4580,1.4570,1.4560,1.4550,1.4540,1.4530,1.4520,1.4510,1.4500])
k_oro_6 = np.array([1.9580,1.9570,1.9560,1.9550,1.9540,1.9530,1.9520,1.9510,1.9500,1.9490,1.9480])

dom_oro_7 = np.array([0.43050,0.43254,0.43458,0.43662,0.43866,0.4407,0.44274,0.44478,0.44682,0.44886,0.4509])
n_oro_7 = np.array([1.4500,1.4430,1.4360,1.4290,1.4220,1.4150,1.4080,1.4010,1.3940,1.3870,1.3800])
k_oro_7 = np.array([1.9480,1.9446,1.9412,1.9378,1.9344,1.9310,1.9276,1.9242,1.9208,1.9174,1.9140])

dom_oro_8 = np.array([0.45090,0.45295,0.455,0.45705,0.4591,0.46115,0.4632,0.46525,0.4673,0.46935,0.4714])
n_oro_8 = np.array([1.3800,1.3730,1.3660,1.3590,1.3520,1.3450,1.3380,1.3310,1.3240,1.3170,1.3100])
k_oro_8 = np.array([1.9140,1.9075,1.9010,1.8945,1.8880,1.8815,1.8750,1.8685,1.8620,1.8555,1.8490])

dom_oro_9 = np.array([0.47140,0.47385,0.4763,0.47875,0.4812,0.48365,0.4861,0.48855,0.491,0.49345,0.4959])
n_oro_9 = np.array([1.3100,1.2830,1.2560,1.2290,1.2020,1.1750,1.1480,1.1210,1.0940,1.0670,1.0400])
k_oro_9 = np.array([1.8490,1.8474,1.8458,1.8442,1.8426,1.8410,1.8394,1.8378,1.8362,1.8346,1.8330])

dom_oro_10 = np.array([0.49590,0.4984,0.5009,0.5034,0.5059,0.5084,0.5109,0.5134,0.5159,0.5184,0.5209])
n_oro_10 = np.array([1.0400,0.99800,0.95600,0.91400,0.87200,0.83000,0.78800,0.74600,0.70400,0.66200,0.62000])
k_oro_10 = np.array([1.8330,1.8578,1.8826,1.9074,1.9322,1.9570,1.9818,2.0066,2.0314,2.0562,2.0810])

dom_oro_11 = np.array([0.52090,0.52367,0.52644,0.52921,0.53198,0.53475,0.53752,0.54029,0.54306,0.54583,0.5486])
n_oro_11 = np.array([0.62000,0.60100,0.58200,0.56300,0.54400,0.52500,0.50600,0.48700,0.46800,0.44900,0.43000])
k_oro_11 = np.array([2.0810,2.1184,2.1558,2.1932,2.2306,2.2680,2.3054,2.3428,2.3802,2.4176,2.4550])

dom_oro_12 = np.array([0.54860,0.55195,0.5553,0.55865,0.562,0.56535,0.5687,0.57205,0.5754,0.57875,0.5821])
n_oro_12 = np.array([0.43000,0.41600,0.40200,0.38800,0.37400,0.36000,0.34600,0.33200,0.31800,0.30400,0.29000])
k_oro_12 = np.array([2.4550,2.4958,2.5366,2.5774,2.6182,2.6590,2.6998,2.7406,2.7814,2.8222,2.8630])

dom_oro_13 = np.array([0.58210,0.58557,0.58904,0.59251,0.59598,0.59945,0.60292,0.60639,0.60986,0.61333,0.61680])
n_oro_13 = np.array([0.29000,0.28200,0.27400,0.26600,0.25800,0.25000,0.24200,0.23400,0.22600,0.21800,0.21000])
k_oro_13 = np.array([2.8630,2.9039,2.9448,2.9857,3.0266,3.0675,3.1084,3.1493,3.1902,3.2311,3.2720])

dom_oro_14 = np.array([0.61680,0.63072,0.64464,0.65856,0.67248,0.6864,0.70032,0.71424,0.72816,0.74208,0.756])
n_oro_14 = np.array([0.21000,0.18718,0.16436,0.14154,0.13712,0.13402,0.13093,0.13189,0.13459,0.13730,0.14000])
k_oro_14 = np.array([3.2720,3.4105,3.5491,3.6876,3.8141,3.9397,4.0653,4.1860,4.3047,4.4233,4.5420])

dom_oro_15 = np.array([0.75600,0.76306,0.77012,0.77718,0.78424,0.7913,0.79836,0.80542,0.81248,0.81954,0.8266])
n_oro_15 = np.array([0.14000,0.14217,0.14434,0.14651,0.14868,0.15084,0.15301,0.15518,0.15735,0.15952,0.16078])
k_oro_15 = np.array([4.5420,4.6007,4.6593,4.7180,4.7767,4.8354,4.8940,4.9527,5.0114,5.0700,5.1280])

# %%
#AUTOMATIZACIÓN PARTE REAL 
lista_dominios_oro = [dom_oro_1,dom_oro_2,dom_oro_3,dom_oro_4,dom_oro_5,dom_oro_6,dom_oro_7,dom_oro_8,dom_oro_9,dom_oro_10,dom_oro_11,dom_oro_12,dom_oro_13,dom_oro_14,dom_oro_15]
lista_n_oro = [n_oro_1,n_oro_2,n_oro_3,n_oro_4,n_oro_5,n_oro_6,n_oro_7,n_oro_8,n_oro_9,n_oro_10,n_oro_11,n_oro_12,n_oro_13,n_oro_14,n_oro_15]

# %%
for x, y in zip(lista_dominios_oro, lista_n_oro) : 
    n = 11 
    x_lambda = x*1000 
    ones= np.ones([n,1]) 
    x_lambda_vector = np.reshape(x_lambda , [n,1])
    y_vector = np.reshape(y, [n,1])
    X = np.hstack((ones, x_lambda_vector))
    n, p = X.shape 
    beta = np.array([0,0]) 
    def funcion(beta, X, y):
        n, p = X.shape
        beta = np.reshape(beta, [p,1])
        y_prediccion = X @ beta 
        error = y_prediccion - y 
        rss = error.T @ error 
        return rss[0,0] 
    import scipy.optimize as opt 
    solucion = opt.minimize(funcion, beta, args=(X,y_vector)) 
    beta0 = solucion.x[0] 
    beta1 = solucion.x[1] 
    print("f(lambda) = " + str(beta1) + "x " + str(beta0))
# Out:
# f(lambda) = 0.0005576872625476304x 1.3592599491595003
# f(lambda) = -0.000976474600061135x 1.8253376024236632
# f(lambda) = -0.0014786992964478999x 2.0239668014757055
# f(lambda) = 0.0005843389149767634x 1.2374292021134004
# f(lambda) = -0.0006772423117168033x 1.7395201636037823
# f(lambda) = -0.0006261247910434782x 1.7191620418850104
# f(lambda) = -0.0034660718761706645x 2.94249786836637
# f(lambda) = -0.003452261947403157x 2.937010589584246
# f(lambda) = -0.011049390478366294x 6.519037697410977
# f(lambda) = -0.016830758912535132x 9.386757823679392
# f(lambda) = -0.006886928798761867x 4.2077851677291775
# f(lambda) = -0.004200293914994961x 2.7346361573943834
# f(lambda) = -0.0023276808189622838x 1.6453282594678902
# f(lambda) = -0.0004356722298504639x 0.4489481383999717
# f(lambda) = 0.0002919580711164882x -0.08026461094326366

# %% [markdown]
# #### ORO PARTE REAL
# f(lambda) = 0.0005576872539878879x +1.3592599518160196
# f(lambda) = -0.0009764745888363448x +1.8253375986336766
# f(lambda) = -0.0014786992882535122x +2.0239667984597576
# f(lambda) = 0.0005843389601585354x +1.2374291845145846
# f(lambda) = -0.0006772423121499798x +1.7395201637793987
# f(lambda) = -0.0006261247409291974x +1.719162020735327
# f(lambda) = -0.003466072150464768x +2.9424979892734218
# f(lambda) = -0.0034522620502964035x +2.9370106370426043
# f(lambda) = -0.011049390480564471x +6.519037698474394
# f(lambda) = -0.016830758928718683x +9.386757831908996
# f(lambda) = -0.006886928163346544x +4.207784827850306
# f(lambda) = -0.004200293983867318x +2.734636196344705
# f(lambda) = -0.0023276808636184696x +1.6453282862461798
# f(lambda) = -0.000435672223460419x +0.4489481339957757
# f(lambda) = 0.0002919580711674397x -0.08026461098361282
#
# #### ORO PARTE IMAGINARIA
# f(lambda) = 0.00045786548315765495x +1.7509610287670974
# f(lambda) = -0.0009740539403336427x +2.2073938411691487
# f(lambda) = 0.002439715626284196x +0.9999505994204927
# f(lambda) = 0.0011503766574311987x +1.494485803307109
# f(lambda) = 0.0003290469952919965x +1.8216207930078334
# f(lambda) = -0.0006261250974515633x +2.2171621711754157
# f(lambda) = -0.0017013659256638245x +2.680791955970597
# f(lambda) = -0.0032083597952736707x +3.361035112154911
# f(lambda) = -0.0006820435421406607x +2.1708703517057555
# f(lambda) = 0.009889241062559955x -3.070690163656001
# f(lambda) = 0.01347408198913787x -4.937265351096474
# f(lambda) = 0.012157915200333241x -4.214477365987187
# f(lambda) = 0.011764537998582878x -3.9847523106694127
# f(lambda) = 0.009086480400603966x -2.3102056091586007
# f(lambda) = 0.00829633616917349x -1.7295999090512537
#
# #### MIS DOMINIOS
# x_ranges_oro = [(0.300,0.32040),(0.32040,0.35420),(0.35420,0.38150),(0.38150,0.39740),(0.39740,0.41330),(0.41330,0.43050),(0.43050,0.45090),(0.45090,0.47140),(0.47140,0.49590),(0.49590,0.52090),(0.52090,0.54860),(0.54860,0.58210),(0.58210,0.61680),(0.61680,0.75600),(0.75600,0.8266)]

# %% [markdown]
# Se procedió a realizar una prueba sencilla para obtener las 2 partes del n_Au a una longitud de onda de 387.4 nm. Los resultados esperados eran de n = 1.4637 y k = 1.9401.

# %%
sm = 0.0005843389601585354*(387.4)+1.2374291845145846
jf = 0.0011503766574311987*(387.4)+1.494485803307109
sm,jf #da suficientemente acertado
# Out:
# (1.4638020976800012, 1.9401417203959552)

# %% [markdown]
# Se comenzó por definir las funciones que darían el valor de n_Au y n_Si como números complejos:

# %%
def ind_ref_Si(lam):
    if lam >= 300 and lam < 310:
        a = 0.001822571095590312*(lam)+ 4.454614314767349
        b = -0.05833779750805829*(lam)+ 21.649888273827735
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 310 and lam < 317.9:
        a = 0.000618203780107485*(lam)+ 4.818942820547491
        b = -0.030521034590783765*(lam)+ 13.048106706630055
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 317.9 and lam < 326.30:
        a = 0.005708934527578188*(lam)+ 3.2016883049663685
        b = -0.019655369361894957*(lam)+ 9.595022091586962
        n_Au = a + (b*1j)
        return n_Au
    if lam >= 326.3 and lam < 335.1:
        a = 0.010208727259668298*(lam)+ 1.7345029677801058
        b = -0.014217280735998934*(lam)+ 7.821682533701889
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 335.1 and lam < 344.4:
        a = 0.015036937195248642*(lam)+ 0.11719884130964744
        b = -0.00775110083572566*(lam)+ 5.655958632432424
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 344.4 and lam < 354.2:
        a =  0.031927106907187*(lam)-5.699110591324737
        b = 0.0026395512141405863*(lam)+ 2.0785230634025753
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 354.2 and lam < 364.7:
        a =  0.08675223409221743*(lam)-25.117063013351682
        b =  -0.0295293270322416*(lam)+13.473858042631385
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 364.7 and lam < 375.7:
        a = 0.016905432699586723*(lam)+ 0.35713481315349227
        b = -0.12601733114333966*(lam)+ 48.664145747960795
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 375.7 and lam < 387.5:
        a = -0.05492198522583452*(lam)+ 27.34375154035692
        b = -0.05856822027610789*(lam)+ 23.324660474906203
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 387.5 and lam < 399.9:
        a = -0.03976769306307591*(lam)+ 21.47256873632867
        b = -0.019687047921568307*(lam)+ 8.259318744123897
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 399.9 and lam < 413.30:
        a =  -0.026052616514425808*(lam)+ 15.989021493932546
        b = -0.008888435003924448*(lam)+ 3.9420652908662266
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 413.30 and lam < 427.50:
        a = -0.01846122925053561*(lam)+ 12.852644505769854
        b =  -0.004726401359058814*(lam)+ 2.223006996374033
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 427.5 and lam < 442.8:
        a = -0.013667242550391284*(lam)+ 10.804328308652249
        b = -0.0026868498573450997*(lam)+ 1.3522104280421496
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 442.8 and lam < 459.2:
        a = -0.010433618620805059*(lam)+ 9.373589774221077
        b = -0.002079958900000417*(lam)+ 1.084589239597811
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 459.2 and lam <= 516.6:
        a = -0.0062816645604509246*(lam)+ 7.445283320179863
        b = -0.001078816688372149*(lam)+ 0.6110485067532602
        n_Au = a + (b*1j)
        return n_Au
    if lam >= 516.6 and lam < 619.9:
        a = -0.0028977603536213038*(lam)+ 5.686415779588927
        b = -0.00033952120568173344*(lam)+ 0.22957403119180284
        n_Au = a + (b*1j)
        return n_Au
    if lam >= 619.9 and lam < 729.3:
        a = -0.0013721892566664834*(lam)+ 4.745901802879681
        b = -0.00010157815841204854*(lam)+ 0.08323363447747698
        n_Au = a + (b*1j)
        return n_Au
    if lam >= 729.3 and lam <= 826.6:
        a = -0.0008153384626206141*(lam)+ 4.346310860361642
        b = -5.7902775623551065e-05*(lam)+ 0.05273253034746406
        n_Au = a + (b*1j)
        return n_Au

# %%
def ind_ref_oro(lam):
    if lam >= 300 and lam < 320.4:
        a = 0.0005576872539878879*(lam)+1.3592599518160196
        b = 0.00045786548315765495*(lam)+ 1.7509610287670974
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 320.4 and lam < 354.2:
        a = -0.0009764745888363448*(lam)+ 1.8253375986336766
        b = -0.0009740539403336427*(lam)+ 2.2073938411691487
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 354.2 and lam < 381.5:
        a = -0.0014786992882535122*(lam)+ 2.0239667984597576
        b = 0.002439715626284196*(lam)+ 0.9999505994204927
        n_Au = a + (b*1j)
        return n_Au
    if lam >= 381.5 and lam < 397.4:
        a = 0.0005843389601585354*(lam)+ 1.2374291845145846
        b = 0.0011503766574311987*(lam)+ 1.494485803307109
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 397.4 and lam < 413.3:
        a = -0.0006772423121499798*(lam)+ 1.7395201637793987
        b = 0.0003290469952919965*(lam)+ 1.8216207930078334
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 413.3 and lam < 430.5:
        a = -0.0006261247409291974*(lam)+ 1.719162020735327 
        b = -0.0006261250974515633*(lam)+ 2.2171621711754157
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 430.5 and lam < 450.9:
        a = -0.003466072150464768*(lam)+ 2.9424979892734218
        b = -0.0017013659256638245*(lam)+ 2.680791955970597
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 450.9 and lam < 471.4:
        a = -0.0034522620502964035*(lam)+ 2.9370106370426043
        b = -0.0032083597952736707*(lam)+ 3.361035112154911
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 471.4 and lam < 495.9:
        a = -0.011049390480564471*(lam)+ 6.519037698474394
        b = -0.0006820435421406607*(lam)+ 2.1708703517057555
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 495.9 and lam < 520.9:
        a = -0.016830758928718683*(lam)+ 9.386757831908996
        b = 0.009889241062559955*(lam)-3.070690163656001
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 520.9 and lam < 548.6:
        a =  -0.006886928163346544*(lam)+ 4.207784827850306
        b = 0.01347408198913787*(lam)-4.937265351096474
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 548.6 and lam < 582.1:
        a = -0.004200293983867318*(lam)+ 2.734636196344705
        b =  0.012157915200333241*(lam)-4.214477365987187
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 582.1 and lam < 616.8:
        a = -0.0023276808636184696*(lam)+ 1.6453282862461798
        b = 0.011764537998582878*(lam)-3.9847523106694127
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 616.8 and lam < 756:
        a = -0.000435672223460419*(lam)+ 0.4489481339957757
        b = 0.009086480400603966*(lam)-2.3102056091586007
        n_Au = a + (b*1j)
        return n_Au 
    if lam >= 756 and lam <= 826.6:
        a = 0.0002919580711674397*(lam)-0.08026461098361282
        b = 0.00829633616917349*(lam)-1.7295999090512537
        n_Au = a + (b*1j)
        return n_Au

# %% [markdown]
# Se definió la función para obtener los valores de fracciones de llenado del Au y SiO2 dependiendo del grosor de cada material. Estos valores son necesarios para poder usar la función de la constante dieléctrica del metamaterial.

# %%
def fracciones_llenado(t_Au, t_SiO2):
    nm_Au = t_Au
    nm_SiO2 = t_SiO2
    f_Au = (nm_Au)/(nm_Au + nm_SiO2) 
    f_SiO2 = (nm_SiO2)/(nm_Au + nm_SiO2) 
    return nm_Au, nm_SiO2, f_Au, f_SiO2

# %%
fracciones_llenado(20,30)
# Out:
# (20, 30, 0.4, 0.6)

# %% [markdown]
# Antes de automatizar el cálculo de R con una función general, se realizó una prueba individual con cada uno de los pasos por separado que tendría que contener la función para corroborar que los cálculos se hacen de manera correcta en el código.

# %%
#PRUEBA INDIVIDUAL PARA IR DEFINIENDO LAS OPERACIONES A REALIZAR 
#Valores de índice de refracción para ambos materiales a 600nm 
n_Au = 0.24873 + 3.0740j 
n_Si = 3.9477595674161448 + 0.02586130778276277j 
#constante dieléctrica del oro 
E_Au = n_Au**2

# %%
E_Au
# Out:
# (-9.3876093871+1.5291920399999999j)

# %%
#tAu = 24, tSiO2 = 86. Grosores seleccionados para realizar esta prueba individual. 
fracciones_llenado(24,86)
# Out:
# (24, 86, 0.21818181818181817, 0.7818181818181819)

# %%
E_meta = 0.21818181818181817 * E_Au + 0.7818181818181819 * 2.46 
E_meta
# Out:
# (-0.12493295718545427+0.3336418996363636j)

# %%
n_meta = cmath.sqrt(E_meta)
n_meta # Valor de n2 en la función final
# Out:
# (0.34009750020674645+0.49050919138414945j)

# %%
n_aire = 1    # Valor de n1 en la función final 
n_n_Si = 3.9477595674161448 + 0.02586130778276277j  # Valor de n3 en la función final 
h = 24 +86 #Grosor total del metamaterial

# %%
beta = ((2*np.pi)/(600)) * n_meta * h 
beta
# Out:
# (0.39176419632304815+0.565026026462595j)

# %%
beta_pori = beta*1j 
beta_pori *2
# Out:
# (-1.13005205292519+0.7835283926460963j)

# %%
r12 = (n_aire-n_meta)/(n_aire+n_meta)
r23 = (n_meta-n_n_Si)/(n_meta+n_n_Si)

# %%
#Función final R 
R_600 = (np.abs((r12+r23*np.exp(2*beta_pori))/(1+r12*r23*np.exp(2*beta_pori))))**2 
R_600 #perfecto. La prueba salió bien pq R siempre debe ser mayor que 0 y menor a 1. La maximiación será el valor de R más bajo de las 3456 opciones que tenemos.
# Out:
# 0.527471981907264

# %%
type(n_Au), n_Au
# Out:
# (complex, (0.24873+3.074j))

# %% [markdown]
# # AUTOMATIZACIÓN CON EL PROGRAMA

# %%
#crear el esqueleto de una fución que reciba o cree los grosores
#Para graficar voy a necesitar una función que cuando yo le meta un arreglo de lambdas me de los valores de R para cada uno. CON LOS GROSORES CONSTANTES 

def R(t_Au, t_SiO2, lam):
    gros_Au,gros_SiO2,f_Au, f_SiO2 = fracciones_llenado(t_Au, t_SiO2)
    n_SiO2 = 1.4691 
    E_SiO2 = 2.46
    n_Au = ind_ref_oro(lam) 
    n_Si = ind_ref_Si(lam) ####n3
    E_Au = n_Au**2 
    E_meta = f_Au * E_Au + f_SiO2* E_SiO2
    n_meta = cmath.sqrt(E_meta) ### n2
    n_aire = 1    ######n1
    h = t_Au + t_SiO2 
    beta = ((2*np.pi)/(lam)) * n_meta * h 
    beta_pori = beta*1j 
    r12 = (n_aire-n_meta)/(n_aire+n_meta)
    r23 = (n_meta-n_n_Si)/(n_meta+n_n_Si)
    R_lam = (np.abs((r12+r23*np.exp(2*beta_pori))/(1+r12*r23*np.exp(2*beta_pori))))**2 
    return R_lam

# %%
R(24,86,600) #funciona bien. Mismo valor que en la prueba por separado.
# Out:
# 0.5274691885072277

# %%
#Graficar la función anterior individual con grosores de Au= 24 y SiO2 = 86 

import numpy as np
import matplotlib.pyplot as plt
rango_lam = np.arange(300, 827, 1)  #de 1 en 1 no incluye el final 
t_Au = 24  
t_SiO2 = 86  
Reflectancias = [R(t_Au, t_SiO2, lam) for lam in rango_lam] 

#Para el minimo de ESTA FUNCIÓN 
indice_min_R = np.argmin(Reflectancias)
min_lam = rango_lam[indice_min_R] 
min_R = Reflectancias[indice_min_R]      

# R en 600 nm
indice_lam_600 = np.where(rango_lam == 600)[0][0] #me dice el índice en donde el valor de lam == 600 #doble indice por tupla y arreglo 
R_600 = Reflectancias[indice_lam_600]


plt.figure(figsize=(10, 6))
plt.plot(rango_lam, Reflectancias, label='Reflectancia $R(\\lambda)$', color='blue') #grafico un np.array y una lista pero se puede pq tienen mismo tamaño

plt.scatter(min_lam, min_R, color='red', label=f'Mínimo: ({min_lam}, {min_R:.4f})')
plt.text(min_lam, min_R, f'({min_lam}, {min_R:.4f})', color='red', fontsize=10, ha='left')

plt.scatter(600, R_600, color='green', label=f'R(600nm): ({600}, {R_600:.4f})')
plt.text(600, R_600, f'({600}, {R_600:.4f})', color='green', fontsize=10, ha='left')


plt.xlabel('Longitud de onda (λ) [nm]')
plt.ylabel('Reflectancia $R$')
plt.title('Reflectancia en función de la longitud de onda')
plt.grid(True)
plt.legend()
plt.show()

# %%
#Función para que me evalué R con ts fijos en todo el rango de lambda y me saque min de esa función y min en 600 nm. Guarda los valores en una lista 
#listas de grosores, de R min, de R en 600 


def evalua_en_rango_lambda(t_Au,t_SiO2):
    rango_lam = np.arange(300, 827, 1)   
    Reflectancias = [R(t_Au, t_SiO2, lam) for lam in rango_lam] #lista con las reflectancias 
    
    #Para el minimo de ESTA FUNCIÓN 
    indice_min_R = np.argmin(Reflectancias)
    min_lam = rango_lam[indice_min_R] 
    min_R = Reflectancias[indice_min_R]      
    
    # R en 600 nm
    indice_lam_600 = np.where(rango_lam == 600)[0][0] #me dice el índice en donde el valor de lam == 600 
    R_600 = Reflectancias[indice_lam_600]
    return t_Au,t_SiO2,min_lam,min_R,R_600

# %%
evalua_en_rango_lambda(24,86)
# Out:
# (24, 86, 473, 0.006404046547320192, 0.5274691885072277)

# %%
#Aplicar ese mismo proceso para todas posibilidades que se tienen. Ir guardando los resultados en arreglos o una matriz global 
#checar longitud arreglos al final para comprobar
#obtener el valor min de R en 600, sacar índices para ver los grosores 

import itertools 

posibles_grosores_Au = range(5, 41) #no incluye final 
posibles_grosores_SiO2 = range(5, 101) #no incluye final 

#3456 combinaciones posibles de grosores si se toma en cuenta que sólo pueden ser enteros 
combinaciones = itertools.product(posibles_grosores_Au, posibles_grosores_SiO2)

lista_grosores_Au = [] 
lista_grosores_SiO2 = [] 
lista_nm_delmin_funcion = [] 
lista_min_de_cada_funcion = [] 
lista_min_en_600 = [] 
for valor1, valor2 in combinaciones:
    grosor_Au,grosor_SiO2,nmdelmin_funcion,R_delmin,R_en600 = evalua_en_rango_lambda(valor1,valor2) 
    lista_grosores_Au.append(grosor_Au)
    lista_grosores_SiO2.append(grosor_SiO2)
    lista_nm_delmin_funcion.append(nmdelmin_funcion)
    lista_min_de_cada_funcion.append(R_delmin)
    lista_min_en_600.append(R_en600)

#Tarda menos de 2 min en calcular todo 
len(lista_grosores_Au),len(lista_grosores_SiO2),len(lista_nm_delmin_funcion),len(lista_min_de_cada_funcion),len(lista_min_en_600)
# Out:
# (3456, 3456, 3456, 3456, 3456)

# %%
arreglo_grosores_Au = np.array(lista_grosores_Au)
arreglo_grosores_SiO2 = np.array(lista_grosores_SiO2)
arreglo_nm_delmin_funcion = np.array(lista_nm_delmin_funcion)
arreglo_min_de_cada_funcion = np.array(lista_min_de_cada_funcion)
arreglo_min_en_600 = np.array(lista_min_en_600)

solucion_al_problema = np.min(arreglo_min_en_600) 

solucion_al_problema #lo min a lo que se puede llegar de reflectancia en 600 nm con este modelo.
# Out:
# 0.10487460298470119

# %%
indice_solucion = np.argmin(arreglo_min_en_600)
indice_solucion
# Out:
# 95

# %%
arreglo_min_en_600[95]
# Out:
# 0.10487460298470119

# %%
arreglo_grosores_Au[95], arreglo_grosores_SiO2[95]
# Out:
# (5, 100)

# %%
indice_arreglo_min_de_cada_funcion = np.argmin(arreglo_min_de_cada_funcion)
indice_arreglo_min_de_cada_funcion
# Out:
# 734

# %%
arreglo_nm_delmin_funcion[734], arreglo_min_de_cada_funcion[734]
# Out:
# (364, 2.593912077969396e-09)

# %%
arreglo_nm_delmin_funcion[95], arreglo_min_de_cada_funcion[95]
# Out:
# (534, 0.07425795255028084)

# %%
#Graficar LA solución
rango_lam_sol = np.arange(300, 827, 1) 
t_Au_sol = 5 
t_SiO2_sol = 100
Reflectancias_sol = [R(t_Au_sol, t_SiO2_sol, lam) for lam in rango_lam_sol] 

#Para el minimo de ESTA FUNCIÓN 
indice_min_R_sol = np.argmin(Reflectancias_sol)
min_lam_sol = rango_lam_sol[indice_min_R_sol] 
min_R_sol = Reflectancias_sol[indice_min_R_sol]      

# R en 600 nm
indice_lam_600_sol = np.where(rango_lam_sol == 600)[0][0]
R_600_sol = Reflectancias_sol[indice_lam_600_sol]


plt.figure(figsize=(10, 6))
plt.plot(rango_lam_sol, Reflectancias_sol, label='Reflectancia $R(\\lambda)$', color='blue') 

plt.scatter(min_lam_sol, min_R_sol, color='red', label=f'Mínimo: ({min_lam_sol}, {min_R_sol:.4f})')
plt.text(min_lam_sol, min_R_sol, f'({min_lam_sol}, {min_R_sol:.4f})', color='red', fontsize=10, ha='left')

plt.scatter(600, R_600_sol, color='green', label=f'R(600nm): ({600}, {R_600_sol:.4f})')
plt.text(600, R_600_sol, f'({600}, {R_600_sol:.4f})', color='green', fontsize=10, ha='left')


plt.xlabel('Longitud de onda (λ) [nm]')
plt.ylabel('Reflectancia $R$')
plt.title('Reflectancia en función de la longitud de onda')
plt.grid(True)
plt.legend()
plt.show()

# %%
# GRAFICA CON LAS 3456 COMBINACIONES. Se ve de forma visual que no hay ningún mínimo justo en 600nm 
posibles_grosores_Au = range(5, 41)  
posibles_grosores_SiO2 = range(5, 101)  

combinaciones = itertools.product(posibles_grosores_Au, posibles_grosores_SiO2)

rango_lam = np.arange(300, 827, 1)

plt.figure(figsize=(10, 6))

for t_Au, t_SiO2 in combinaciones:
    Reflectancias = [R(t_Au, t_SiO2, lam) for lam in rango_lam]
    
    plt.plot(rango_lam, Reflectancias, color=np.random.rand(3,), lw=0.5)  

    indice_min_R = np.argmin(Reflectancias)
    min_lam = rango_lam[indice_min_R] 
    min_R = Reflectancias[indice_min_R]      

    indice_lam_600 = np.where(rango_lam == 600)[0][0] 
    R_600 = Reflectancias[indice_lam_600]
    
    plt.scatter(min_lam, min_R, s=1, color='red',zorder=3)
    plt.scatter(600, R_600, s=1, color='green',zorder=3) 

plt.xlabel('Longitud de onda (λ) [nm]')
plt.ylabel('Reflectancia $R$')
plt.title('Reflectancia en función de la longitud de onda')
plt.grid(True)
plt.show()

# %% [markdown]
# El procedimiento anterior para optimizar la función R y encontrar su mínimo en 600nm se realizó por medio de la librería intertools y ciclos. Sin embargo también se podría realizar con ayuda de un proceso Gaussiano, como se muestra a continuación

# %%
t_Au_gaussianos = np.arange(5,41,1)
t_SiO2_gaussianos = np.arange(5,101,1)

# %%
escoge_t_Au = np.random.choice(t_Au_gaussianos,5,False)
escoge_t_Si2 = np.random.choice(t_SiO2_gaussianos,5,False)
lista_de_R = []
for i in range(5):
    valor = R(escoge_t_Au[i], escoge_t_Si2[i],600)
    lista_de_R.append(valor) 

vector_t_Au = escoge_t_Au.reshape([-1,1]) 
vector_t_SiO2 = escoge_t_Si2.reshape([-1,1]) 
X = np.hstack((vector_t_Au, vector_t_SiO2))

vector_R = np.array(lista_de_R).reshape([-1,1])

# %%
#Se pueden graficar estos puntos iniciales para tener una comparación de la "altura" R que estamos queriendo minimizar 

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

x = vector_t_Au 
y = vector_t_SiO2
z = vector_R 

indice_min = np.argmin(z)
x_min = x[indice_min][0]
y_min = y[indice_min][0]
z_min = z[indice_min][0]

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c=z, cmap='viridis', marker='o')  
ax.scatter(x_min, y_min, z_min, color='red', s=100, label='Mínimo') 
ax.text(x_min, y_min, z_min, f"({x_min}, {y_min}, {z_min:.2f})", color='red', fontsize=10)

ax.set_xlabel('t_Au')
ax.set_ylabel('t_SiO2')
ax.set_zlabel('R')
ax.set_title('R en función de t_Au y t_SiO2')
plt.show()

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

from sklearn.gaussian_process import GaussianProcessRegressor 
from sklearn.gaussian_process.kernels import RBF

for i in range(30): 
    kernel = 1.0*RBF(length_scale=1)
    gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer =10).fit(X, vector_R) 
    x_t_Au = np.linspace(5,40,100).reshape([-1,1]).astype(int)
    x_t_SiO2 = np.linspace(5,100,100).reshape([-1,1]).astype(int)
    x_prueba = np.hstack((x_t_Au ,x_t_SiO2))
    y_pred, y_std = gp.predict(x_prueba, return_std=True) 
    y_pred_low = y_pred - 1.96*y_std
    y_pred_high = y_pred + 1.96*y_std
    i_min = np.argmin(y_pred) 
    X = np.vstack((X, x_prueba[i_min]))
    vector_R = np.vstack((vector_R, [[y_pred[i_min]]])) 
    
#termina el ciclo pero se debe hacer la regresión una vez más con la última matriz obtenida 
kernel = 1.0*RBF(length_scale=1)
gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer =10).fit(X, vector_R) 
x_t_Au = np.linspace(5,40,100).reshape([-1,1]).astype(int)
x_t_SiO2 = np.linspace(5,100,100).reshape([-1,1]).astype(int)
x_prueba = np.hstack((x_t_Au ,x_t_SiO2))
y_pred, y_std = gp.predict(x_prueba, return_std=True) 
y_pred_low = y_pred - 1.96*y_std
y_pred_high = y_pred + 1.96*y_std
i_min = np.argmin(y_pred)
X = np.vstack((X, x_prueba[i_min]))
vector_R = np.vstack((vector_R, [[y_pred[i_min]]])) 

nuevo_i_min = np.argmin(vector_R)
X[nuevo_i_min], vector_R[nuevo_i_min]
# Out:
# (array([5, 6]), array([-0.00571347]))

# %%
R(5,6,600)
# Out:
# 0.38648212881830135

# %%
x2 = X[:,0] 
y2 = X[:,1]
z2 = vector_R 
indice_min2 = np.argmin(z2)

x_min2 = x2[indice_min2].item()
y_min2 = y2[indice_min2].item()
z_min2 = z2[indice_min2].item()

fig = plt.figure(figsize=(10, 7))
ax2 = fig.add_subplot(111, projection='3d')
ax2.scatter(x2, y2, z2, c=z2, cmap='viridis', marker='o')  
ax2.scatter(x_min2, y_min2, z_min2, color='red', s=100, label='Mínimo') 
ax2.text(x_min2, y_min2, z_min2, f"({x_min2}, {y_min2}, {z_min2:.2f})", color='red', fontsize=10)
ax2.set_xlabel('t_Au')
ax2.set_ylabel('t_SiO2')
ax2.set_zlabel('R')
ax2.set_title('R en función de t_Au y t_SiO2')
plt.show()

# %% [markdown]
# ## INTERPRETACIÓN DE LOS RESULTADOS
# Tango de forma numérica como visual se puede observar que los grosores óptimos para minimizar la reflectancia del metamaterial a 600nm son de 5nm para el oro y 100nm para el dióxido de silicio. Es decir, el valor más pequeño para el oro y el más grande para el dióxido de silicio.
#
# - se esperaba el valle en 600 puede eberse a los limites malos
# - la respuesta no es incorrecta pq con la grafica grande se ve que ningún mínimo llego ahçi.
# - Ya no es problema pq el programa es capaz de hacer los cálculso y combinaciones con cualquier limite, se puede seguir usando después
# - Se observa que las graficas individuales de R son funciones no convexas con varios mínimos locales, por lo que es necesario comparar R a lo largo de todos los valores de lambda para poder minimizar de forma correcta
# - gaussiano no funciona

# %% [markdown]
# ## CONCLUSIONES
# -respondele a los objetivos
# -Cual fue la dificultad de hacer este modelo?
# -Se logró lo esperado?
# -El siguiente pasó consistirá en hacerlo en físico para comparar los valores teóricos con los exprimentales

# %% [markdown]
# ## REFERENCIAS

# %% [markdown]
# - Maldonado, Y. (2024, 15 mayo). Usos del oro. GEOLOGÍA WEB. https://geologiaweb.com/minerales/usos-del-oro/
# - Tom. (2022, 5 noviembre).AccSci Ingenics. https://www.accscicn.com/es/insight/que-son-los-metamateriales/
# - Ruiz, G. (2024, 10 junio). Propiedades del Oro: usos, aleaciones y características. Compro oro chamberí. https://orochamberi.com/blog/propiedades-del-oro/
# - JL, B. (2024, 10 octubre). ¿Qué es un Dieléctrico y Para que Sirve? Electrónica Online. https://electronicaonline.net/electronica/dielectrico/
# - Ingenierizando. (2024, 16 enero). Constante dieléctrica. Ingenierizando. https://www.ingenierizando.com/electronica/constante-dielectrica/
# - Ingenierizando. (2023, 23 marzo). Índice de refracción. Ingenierizando. https://www.ingenierizando.com/optica/indice-de-refraccion/
# - Wikipedia. (s.f.). Ecuaciones de Fresnel. Recuperado el 1 de diciembre de 2024, de https://es.wikipedia.org/wiki/Ecuaciones_de_Fresnel
# - Johnson, P. B., & Christy, R. W. (1972). Optical constants of the noble metals. Physical Review B, 6(12), 4370-4379. Recuperado de https://refractiveindex.info/?shelf=main&book=Au&page=Johnson
# -
# Infinitia Research. (2020, 30 de noviembre). Metamateriales: ¿Qué son y cuáles son sus propiedades? Recuperado de https://www.infinitiaresearch.com/noticias/metamateriales-que-son-propiedade
# -  Pérez Barrera, J. (2022, 8 de septiembre). Metamateriales ¿qué son? CIDESI. Recuperado de https://cidesi.com/metamateriales-que-son/
# -   SciELO. (2016). Metamateriales: Exploración de nuevas propiedades y aplicaciones. Revista Colombiana de Física, 48(3), 1-10. Recuperado de http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0370-39082016000300002
# s300002
